# %% [markdown]
# # Name: Jayaram Kurtadi
#
# email : jayaramk998@gmail.com
# Linkedin: https://www.linkedin.com/in/jayaram98/
# Data analytics project with python
#
# # 1. Weather Data Analysis Project

# %% [markdown]
# Importing library and modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing dataset

# %%
df = pd.read_csv("C:/Users/Administrator/Desktop/Jupyter/Python project/1. Weather Data.csv")

# %% [markdown]
# # Analysing DataFrames

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
# Basic information about our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# Here you can see Date/Time is in Object formate,. We need to change it to Date/Time formate
def change_into_datetime(col):
    df[col] = pd.to_datetime(df[col])
    
for i in ["Date/Time"]:
    change_into_datetime(i)

# %%
# Now you can see it changed into datetime formate
df.dtypes
# Out:
# Date/Time           datetime64[ns]
# Temp_C                     float64
# Dew Point Temp_C           float64
# Rel Hum_%                    int64
# Wind Speed_km/h              int64
# Visibility_km              float64
# Press_kPa                  float64
# Weather                     object
# dtype: object

# %%
# See total unique value in Weather columns
df["Weather"].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
# Count total number of unique value in Weather columns
df["Weather"].nunique()
# Out:
# 50

# %%
# See total number of unique value with count
df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# See totla number of unique value in all columns
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
# See total number of non null value in this dataframe
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   datetime64[ns]
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(1)
# memory usage: 549.1+ KB

# %% [markdown]
# # Q/ Find all the unique "Wind Speed" value in the data

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df["Wind Speed_km/h"].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df["Wind Speed_km/h"].nunique()
# Out:
# 34

# %% [markdown]
# # Q/ Find the number of times when the "Wether is exactly clear"

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
# using value_count()
df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# Using filtering
df[df.Weather == "Clear"].head()
# Out:
#               Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67  2012-01-03 19:00:00   -16.9             -24.8         50               24
# 114 2012-01-05 18:00:00    -7.1             -14.4         56               11
# 115 2012-01-05 19:00:00    -9.2             -15.4         61                7
# 116 2012-01-05 20:00:00    -9.8             -15.7         62                9
# 117 2012-01-05 21:00:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
# using groupby
df.groupby("Weather").get_group("Clear")
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 67   2012-01-03 19:00:00   -16.9             -24.8         50
# 114  2012-01-05 18:00:00    -7.1             -14.4         56
# 115  2012-01-05 19:00:00    -9.2             -15.4         61
# 116  2012-01-05 20:00:00    -9.8             -15.7         62
# 117  2012-01-05 21:00:00    -9.0             -14.8         63
# ...                  ...     ...               ...        ...
# 8646 2012-12-26 06:00:00   -13.4             -14.8         89
# 8698 2012-12-28 10:00:00    -6.1              -8.6         82
# 8713 2012-12-29 01:00:00   -11.9             -13.6         87
# 8714 2012-12-29 02:00:00   -11.8             -13.1         90
# 8756 2012-12-30 20:00:00   -13.8             -16.5         80
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather
# 67                 24           25.0     101.74   Clear
# 114                11           25.0     100.71   Clear
# ...

# %% [markdown]
# # Q/ Find the number of times when the "Wind speed was exactly 4 km/hr"

# %%
df.groupby("Wind Speed_km/h").get_group(4)
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 96   2012-01-05 00:00:00    -8.8             -11.7         79
# 101  2012-01-05 05:00:00    -7.0              -9.5         82
# 146  2012-01-07 02:00:00    -8.1             -11.1         79
# ...                  ...     ...               ...        ...
# 8768 2012-12-31 08:00:00    -8.6             -10.3         87
# 8769 2012-12-31 09:00:00    -8.1              -9.6         89
# 8770 2012-12-31 10:00:00    -7.4              -8.9         89
# 8772 2012-12-31 12:00:00    -5.8              -7.5         88
# 8773 2012-12-31 13:00:00    -4.6              -6.6         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa       Weather
# 0                   4            8.0     101.24           Fog
# 1                   4            8.0     101.24           Fog
# ...

# %% [markdown]
# # Q/ Find out All null value in data

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# # Q/ Rename the column name "Weather of the dataframe" to Weather condition

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
df.rename(columns={"Weather":"Weather condition"}, inplace = True)

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# # Q/ What is the mean Visibility?

# %%
df.Visibility_km.mean()
# Out:
# 27.66444672131151

# %% [markdown]
# # Q/ What is the standard deviation of "Pressure" in this data

# %%
# This formate is used, if there is no space in columns name
df.Press_kPa.std()
# Out:
# 0.8440047459486474

# %% [markdown]
# # Q/ What is the variance of "Relative Humidity"

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
# This formate is used, if there is space in columns name
df["Rel Hum_%"].var()
# Out:
# 286.2485501984998

# %% [markdown]
# # Q/ Find all instance when "Snow" was recorded

# %%
df[df["Weather condition"] == "Snow"]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 55   2012-01-03 07:00:00   -14.0             -19.5         63
# 84   2012-01-04 12:00:00   -13.7             -21.7         51
# 86   2012-01-04 14:00:00   -11.3             -19.0         53
# 87   2012-01-04 15:00:00   -10.2             -16.3         61
# 88   2012-01-04 16:00:00    -9.4             -15.5         61
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather condition
# 55                 19           25.0     100.95              Snow
# 84                 11           24.1     101.25              Snow
# ...

# %% [markdown]
# # Q/ Find all instance when "Wind Speed is above 24" and visivility is 25

# %%
df[(df["Wind Speed_km/h"] > 24 ) & (df["Visibility_km"] == 25)]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 23   2012-01-01 23:00:00     5.3               2.0         79
# 24   2012-01-02 00:00:00     5.2               1.5         77
# 25   2012-01-02 01:00:00     4.6               0.0         72
# 26   2012-01-02 02:00:00     3.9              -0.9         71
# 27   2012-01-02 03:00:00     3.7              -1.5         69
# ...                  ...     ...               ...        ...
# 8705 2012-12-28 17:00:00    -8.6             -12.0         76
# 8753 2012-12-30 17:00:00   -12.1             -15.8         74
# 8755 2012-12-30 19:00:00   -13.4             -16.5         77
# 8759 2012-12-30 23:00:00   -12.1             -15.1         78
# 8760 2012-12-31 00:00:00   -11.1             -14.4         77
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather condition
# 23                 30           25.0      99.31            Cloudy
# 24                 35           25.0      99.26      Rain Showers
# ...

# %% [markdown]
# # Q/ What is the minimum & maxmium value of each column against each "Weather condition"

# %%
df.groupby("Weather condition").mean()  # min(), max() can also be used
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# # Q/ Show all the record where weather condition is Fog

# %%
df.head(2)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0 2012-01-01 00:00:00    -1.8              -3.9         86                4
# 1 2012-01-01 01:00:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
df[df["Weather condition"] =="Fog"]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8716 2012-12-29 04:00:00   -16.0             -17.2         90
# 8717 2012-12-29 05:00:00   -14.8             -15.9         91
# 8718 2012-12-29 06:00:00   -13.8             -15.3         88
# 8719 2012-12-29 07:00:00   -14.8             -16.4         88
# 8722 2012-12-29 10:00:00   -12.0             -13.3         90
#
#       Wind Speed_km/h  Visibility_km  Press_kPa Weather condition
# 0                   4            8.0     101.24               Fog
# 1                   4            8.0     101.24               Fog
# ...

# %% [markdown]
# # Q/ Find all instance when "Weather is clear" or "Visivility is above 40"

# %%
df[(df["Weather condition"] == "Clear") | (df["Visibility_km"] > 40)].head()
# Out:
#               Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67  2012-01-03 19:00:00   -16.9             -24.8         50               24
# 106 2012-01-05 10:00:00    -6.0             -10.0         73               17
# 107 2012-01-05 11:00:00    -5.6             -10.2         70               22
# 108 2012-01-05 12:00:00    -4.7              -9.6         69               20
# 109 2012-01-05 13:00:00    -4.4              -9.7         66               26
#
#      Visibility_km  Press_kPa Weather condition
# 67            25.0     101.74             Clear
# 106           48.3     100.45      Mainly Clear
# 107           48.3     100.41      Mainly Clear
# 108           48.3     100.38      Mainly Clear
# 109           48.3     100.40      Mainly Clear
